# %% [markdown]
# IMPORT THE LIBRARY

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# GETTING THE DATASET.

# %%
df = pd.read_csv("/content/Toyota.csv")
df
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# 0     three    1165
# 1         3    1165
# 2         3    1165
# 3         3    1165
# 4         3    1170
# ...     ...     ...
# 1431      3    1025
# 1432      3    1015
# 1433      3    1015
# 1434      3    1015
# 1435      5    1114
#
# [1436 rows x 11 columns]

# %% [markdown]
# TO DROP UNWANTED COLOUM.

# %%
df.drop(["Unnamed: 0","New_Price"],axis=1,inplace=True)

# %% [markdown]
# TOTAL NO OF RECORDS AND FEATURES.

# %%
df.shape
# Out:
# (6019, 12)

# %% [markdown]
# CHECK IF THERE IS ANY NULL VALUES

# %%
df.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64

# %%
plt.figure(figsize=(7,5))
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# DATA CLEANING AND MINING PROCESS AND VISULIZATION.

# %% [markdown]
# LOCATION.

# %%
df['Location'].value_counts()
# Out:
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Ahmedabad     224
# Name: Location, dtype: int64

# %% [markdown]
# FULE

# %%
df['Fuel_Type'].value_counts()
# Out:
# Diesel      3205
# Petrol      2746
# CNG           56
# LPG           10
# Electric       2
# Name: Fuel_Type, dtype: int64

# %%
df[(df['Fuel_Type']=='Electric') | (df['Fuel_Type']=='LPG')]
# Out:
#                                  Name   Location  Year  Kilometers_Driven  \
# 5     Hyundai EON LPG Era Plus Option  Hyderabad  2012              75000
# 936       Maruti Wagon R LXI LPG BSIV  Hyderabad  2012              72000
# 987      Maruti Wagon R LXI DUO BSIII     Mumbai  2008              64226
# 2278      Hyundai Santro Xing GLS LPG       Pune  2010              55000
# 2385      Hyundai Santro Xing GLS LPG  Hyderabad  2011              17000
# 2436            Hyundai i10 Magna LPG     Jaipur  2012              53000
# 2941  Hyundai Santro Xing GL Plus LPG  Hyderabad  2014              56000
# 3595      Maruti Wagon R LX DUO BSIII  Hyderabad  2007              65047
# 4446             Mahindra E Verito D4    Chennai  2016              50000
# 4904        Toyota Prius 2009-2016 Z4     Mumbai  2011              44000
# 5506      Maruti Wagon R Duo LX BSIII  Hyderabad  2012              72389
# 5997           Maruti Wagon R Duo Lxi     Jaipur  2010              70000
#
#      Fuel_Type Transmission Owner_Type      Mileage   Engine      Power  \
# 5          LPG       Manual      First   21.1 km/kg   814 CC   55.2 bhp
# 936        LPG       Manual      First   26.2 km/kg   998 CC   58.2 bhp
# 987        LPG       Manual      First   17.3 km/kg  1061 CC   57.5 bhp
# 2278       LPG       Manual     Second  13.45 km/kg  1086 CC   62.1 bhp
# 2385       LPG       Manual      First  13.45 km/kg  1086 CC   62.1 bhp
# 2436       LPG       Manual     Second   19.2 km/kg  1086 CC  68.05 bhp
# 2941       LPG       Manual      First  13.45 km/kg  1086 CC   62.1 bhp
# 3595       LPG       Manual      First   17.3 km/kg  1061 CC   57.5 bhp
# 4446  Electric    Automatic      First          NaN    72 CC     41 bhp
# 4904  Electric    Automatic      First          NaN  1798 CC     73 bhp
# 5506       LPG       Manual      First   26.2 km/kg   998 CC   58.2 bhp
# 5997       LPG       Manual      First   26.2 km/kg   998 CC   58.2 bhp
#
#       Seats  Price
# 5       5.0   2.35
# 936     5.0   2.85
# 987     5.0   1.45
# 2278    5.0   1.65
# 2385    5.0   3.10
# 2436    5.0   2.85
# 2941    5.0   3.20
# 3595    5.0   1.95
# 4446    5.0  13.00
# 4904    5.0  12.75
# 5506    5.0   3.20
# 5997    5.0   2.27

# %% [markdown]
# ELECTRIC AND FULE

# %%
i =df[(df['Fuel_Type']=='LPG') | (df['Fuel_Type']=='Electric')].index
df.drop(i,axis=0,inplace=True)
df

# %% [markdown]
# TRANSMINISSION

# %%
df['Transmission'].value_counts()
# Out:
# Manual       4289
# Automatic    1718
# Name: Transmission, dtype: int64

# %% [markdown]
# OWNER TYPE

# %%
df['Owner_Type'].value_counts()
# Out:
# First             4919
# Second             966
# Third              113
# Fourth & Above       9
# Name: Owner_Type, dtype: int64

# %% [markdown]
# SEATS

# %%
df['Seats'].value_counts()
# Out:
# 5.0     5002
# 7.0      674
# 8.0      134
# 4.0       99
# 6.0       31
# 2.0       16
# 10.0       5
# 9.0        3
# 0.0        1
# Name: Seats, dtype: int64

# %%
df[df['Seats']>8]
# Out:
#                                        Name   Location  Year  \
# 814                     Toyota Qualis FS B2       Pune  2004
# 917                            Tata Sumo DX     Mumbai  2013
# 1347              Mahindra Scorpio LX BS IV  Bangalore  2007
# 1907                    Toyota Qualis FS B3  Bangalore  2002
# 2267                    Toyota Qualis RS E2       Pune  2004
# 2312        Chevrolet Tavera LT 9 Str BS IV    Kolkata  2012
# 2359                  Mahindra Xylo D2 Maxx    Chennai  2016
# 2575  Chevrolet Tavera LS B3 10 Seats BSIII  Hyderabad  2015
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 814               77757    Diesel       Manual     Second   13.1 kmpl
# 917               20000    Diesel       Manual      First  14.07 kmpl
# 1347              74112    Diesel       Manual      First  12.05 kmpl
# 1907              63000    Diesel       Manual      Third   13.1 kmpl
# 2267             215750    Diesel       Manual     Second    0.0 kmpl
# 2312              67132    Diesel       Manual      First  13.58 kmpl
# 2359             150000    Diesel       Manual      First  14.95 kmpl
# 2575             120000    Diesel       Manual      First   14.8 kmpl
#
#        Engine     Power  Seats  Price
# 814   2446 CC    75 bhp   10.0   3.50
# 917   1978 CC  83.1 bhp   10.0   5.25
# 1347  2179 CC   120 bhp    9.0   4.10
# 1907  2446 CC    75 bhp   10.0   3.65
# 2267  2446 CC  null bhp   10.0   3.50
# 2312  2499 CC    78 bhp    9.0   4.75
# 2359  2489 CC  93.7 bhp    9.0   4.50
# 2575  2499 CC    80 bhp   10.0   5.50

# %%
df['Seats']=np.where(df['Seats']>8,6,df['Seats'])

# %% [markdown]
# TO DROP IF SEATS IS ZERO

# %%
df.drop(df[df['Seats']==0].index,axis=0,inplace=True)

# %% [markdown]
# TO SROUP BY NAME AND TAKE TOTAL NO OF COUNTS

# %%
df['Name'].value_counts()
# Out:
# Mahindra XUV500 W8 2WD                 49
# Maruti Swift VDI                       45
# Maruti Swift Dzire VDI                 34
# Honda City 1.5 S MT                    34
# Maruti Swift VDI BSIV                  31
#                                        ..
# Mahindra Scorpio DX 2.6 Turbo 8 Str     1
# Toyota Qualis FS B2                     1
# Porsche Panamera Diesel 250hp           1
# Honda Amaze VX Diesel                   1
# Mahindra Xylo D4 BSIV                   1
# Name: Name, Length: 1864, dtype: int64

# %%
df['Name'].nunique()
# Out:
# 1864

# %%
df['Model']=df['Name'].map(lambda x: str(x).strip().split(" "))

# %%
df['Name']=df['Name'].map(lambda x: str(x).strip().split(" ")[0])
df
# Out:
#            Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0        Maruti      Mumbai  2010              72000       CNG       Manual
# 1       Hyundai        Pune  2015              41000    Diesel       Manual
# 2         Honda     Chennai  2011              46000    Petrol       Manual
# 3        Maruti     Chennai  2012              87000    Diesel       Manual
# 4          Audi  Coimbatore  2013              40670    Diesel    Automatic
# ...         ...         ...   ...                ...       ...          ...
# 6014     Maruti       Delhi  2014              27365    Diesel       Manual
# 6015    Hyundai      Jaipur  2015             100000    Diesel       Manual
# 6016   Mahindra      Jaipur  2012              55000    Diesel       Manual
# 6017     Maruti     Kolkata  2013              46000    Petrol       Manual
# 6018  Chevrolet   Hyderabad  2011              47000    Diesel       Manual
#
#      Owner_Type     Mileage   Engine      Power  Seats  Price  \
# 0         First  26.6 km/kg   998 CC  58.16 bhp    5.0   1.75
# 1         First  19.67 kmpl  1582 CC  126.2 bhp    5.0  12.50
# 2         First   18.2 kmpl  1199 CC   88.7 bhp    5.0   4.50
# 3         First  20.77 kmpl  1248 CC  88.76 bhp    7.0   6.00
# 4        Second   15.2 kmpl  1968 CC  140.8 bhp    5.0  17.74
# ...         ...         ...      ...        ...    ...    ...
# 6014      First   28.4 kmpl  1248 CC     74 bhp    5.0   4.75
# 6015      First   24.4 kmpl  1120 CC     71 bhp    5.0   4.00
# 6016     Second   14.0 kmpl  2498 CC    112 bhp    8.0   2.90
# 6017      First   18.9 kmpl   998 CC   67.1 bhp    5.0   2.65
# 6018      First  25.44 kmpl   936 CC   57.6 bhp    5.0   2.50
#
#                                         Model
# 0                [Maruti, Wagon, R, LXI, CNG]
# 1     [Hyundai, Creta, 1.6, CRDi, SX, Option]
# 2                            [Honda, Jazz, V]
# 3                       [Maruti, Ertiga, VDI]
# 4      [Audi, A4, New, 2.0, TDI, Multitronic]
# ...                                       ...
# 6014                     [Maruti, Swift, VDI]
# 6015           [Hyundai, Xcent, 1.1, CRDi, S]
# 6016               [Mahindra, Xylo, D4, BSIV]
# 6017                  [Maruti, Wagon, R, VXI]
# 6018                [Chevrolet, Beat, Diesel]
#
# [6006 rows x 13 columns]

# %% [markdown]
# TO GROUP BY YEAR OF PRODUCTION

# %%
df['Year'].value_counts()
# Out:
# 2014    796
# 2015    744
# 2016    740
# 2013    649
# 2017    587
# 2012    575
# 2011    464
# 2010    340
# 2018    298
# 2009    198
# 2008    173
# 2007    124
# 2019    102
# 2006     78
# 2005     57
# 2004     31
# 2003     17
# 2002     15
# 2001      8
# 2000      4
# 1998      4
# 1999      2
# Name: Year, dtype: int64

# %%
df['Year'].value_counts()
# Out:
# 2014    796
# 2015    744
# 2016    740
# 2013    649
# 2017    587
# 2012    575
# 2011    464
# 2010    340
# 2018    298
# 2009    198
# 2008    173
# 2007    124
# 2019    102
# 2006     78
# 2005     57
# 2004     31
# 2003     17
# 2002     15
# 2001      8
# 2000      4
# 1998      4
# 1999      2
# Name: Year, dtype: int64

# %% [markdown]
# TO CHECK THE KILLOMETER IS NULL VALUE

# %%
df['Kilometers_Driven'].isnull().sum()
# Out:
# 0

# %% [markdown]
# TO CKECK THE DATA TYPES

# %%
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# Model                 object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               0
# Engine               36
# Power                36
# Seats                42
# Price                 0
# Model                 0
# dtype: int64

# %% [markdown]
# TO GROUP BY MILAGE.

# %%
df['Mileage'].unique
# Out:
# <bound method Series.unique of 0       26.6 km/kg
# 1       19.67 kmpl
# 2        18.2 kmpl
# 3       20.77 kmpl
# 4        15.2 kmpl
#            ...
# 6014     28.4 kmpl
# 6015     24.4 kmpl
# 6016     14.0 kmpl
# 6017     18.9 kmpl
# 6018    25.44 kmpl
# Name: Mileage, Length: 6006, dtype: object>

# %% [markdown]
# TO GROUP BY ENGINE

# %%
df['Engine'].unique
# Out:
# <bound method Series.unique of 0        998 CC
# 1       1582 CC
# 2       1199 CC
# 3       1248 CC
# 4       1968 CC
#          ...
# 6014    1248 CC
# 6015    1120 CC
# 6016    2498 CC
# 6017     998 CC
# 6018     936 CC
# Name: Engine, Length: 6006, dtype: object>

# %%
df['Mileage']=df['Mileage'].map(lambda x: str(x).strip().split(" ")[0])
df
# Out:
#            Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0        Maruti      Mumbai  2010              72000       CNG       Manual
# 1       Hyundai        Pune  2015              41000    Diesel       Manual
# 2         Honda     Chennai  2011              46000    Petrol       Manual
# 3        Maruti     Chennai  2012              87000    Diesel       Manual
# 4          Audi  Coimbatore  2013              40670    Diesel    Automatic
# ...         ...         ...   ...                ...       ...          ...
# 6014     Maruti       Delhi  2014              27365    Diesel       Manual
# 6015    Hyundai      Jaipur  2015             100000    Diesel       Manual
# 6016   Mahindra      Jaipur  2012              55000    Diesel       Manual
# 6017     Maruti     Kolkata  2013              46000    Petrol       Manual
# 6018  Chevrolet   Hyderabad  2011              47000    Diesel       Manual
#
#      Owner_Type Mileage   Engine      Power  Seats  Price  \
# 0         First    26.6   998 CC  58.16 bhp    5.0   1.75
# 1         First   19.67  1582 CC  126.2 bhp    5.0  12.50
# 2         First    18.2  1199 CC   88.7 bhp    5.0   4.50
# 3         First   20.77  1248 CC  88.76 bhp    7.0   6.00
# 4        Second    15.2  1968 CC  140.8 bhp    5.0  17.74
# ...         ...     ...      ...        ...    ...    ...
# 6014      First    28.4  1248 CC     74 bhp    5.0   4.75
# 6015      First    24.4  1120 CC     71 bhp    5.0   4.00
# 6016     Second    14.0  2498 CC    112 bhp    8.0   2.90
# 6017      First    18.9   998 CC   67.1 bhp    5.0   2.65
# 6018      First   25.44   936 CC   57.6 bhp    5.0   2.50
#
#                                         Model
# 0                [Maruti, Wagon, R, LXI, CNG]
# 1     [Hyundai, Creta, 1.6, CRDi, SX, Option]
# 2                            [Honda, Jazz, V]
# 3                       [Maruti, Ertiga, VDI]
# 4      [Audi, A4, New, 2.0, TDI, Multitronic]
# ...                                       ...
# 6014                     [Maruti, Swift, VDI]
# 6015           [Hyundai, Xcent, 1.1, CRDi, S]
# 6016               [Mahindra, Xylo, D4, BSIV]
# 6017                  [Maruti, Wagon, R, VXI]
# 6018                [Chevrolet, Beat, Diesel]
#
# [6006 rows x 13 columns]

# %%
df['Mileage']=df['Mileage'].astype(float)

# %% [markdown]
# TO GROUP BY ENGINE

# %%
df['Engine'].unique
# Out:
# <bound method Series.unique of 0        998 CC
# 1       1582 CC
# 2       1199 CC
# 3       1248 CC
# 4       1968 CC
#          ...
# 6014    1248 CC
# 6015    1120 CC
# 6016    2498 CC
# 6017     998 CC
# 6018     936 CC
# Name: Engine, Length: 6006, dtype: object>

# %%
def fun(x):
    if x == None:
        return x
    elif len(str(x).split(" "))==2:
        return str(x).split(" ")[0]

# %%
df['Engine']=df['Engine'].apply(fun)

# %%
df['Engine'].isnull().sum()
# Out:
# 36

# %%
df['Engine']=df['Engine'].astype(float)

# %% [markdown]
# TO GROUP BY POWER

# %%
df['Power'].isnull().sum()
# Out:
# 36

# %%
df['Power'].unique
# Out:
# <bound method Series.unique of 0       58.16 bhp
# 1       126.2 bhp
# 2        88.7 bhp
# 3       88.76 bhp
# 4       140.8 bhp
#           ...
# 6014       74 bhp
# 6015       71 bhp
# 6016      112 bhp
# 6017     67.1 bhp
# 6018     57.6 bhp
# Name: Power, Length: 6006, dtype: object>

# %%
df['Power']=df['Power'].apply(fun)

# %%
df['Power'].unique
# Out:
# <bound method Series.unique of 0       58.16
# 1       126.2
# 2        88.7
# 3       88.76
# 4       140.8
#         ...
# 6014       74
# 6015       71
# 6016      112
# 6017     67.1
# 6018     57.6
# Name: Power, Length: 6006, dtype: object>

# %%
df['Power'].isnull().sum()
# Out:
# 36

# %%
df[df['Power'].isnull()]
# Out:
#          Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 194     Honda   Ahmedabad  2007              60006    Petrol       Manual
# 208    Maruti     Kolkata  2010              42001    Petrol       Manual
# 733    Maruti     Chennai  2006              97800    Petrol       Manual
# 749      Land      Mumbai  2008              55001    Diesel    Automatic
# 1294    Honda       Delhi  2009              55005    Petrol       Manual
# 1327   Maruti   Hyderabad  2015              50295    Petrol       Manual
# 1385    Honda        Pune  2004             115000    Petrol       Manual
# 1460     Land  Coimbatore  2008              69078    Petrol       Manual
# 2074   Maruti        Pune  2011              24255    Petrol       Manual
# 2096  Hyundai  Coimbatore  2004              52146    Petrol       Manual
# 2264   Toyota        Pune  2012              24500    Petrol       Manual
# 2325   Maruti        Pune  2015              67000    Petrol       Manual
# 2335   Maruti      Mumbai  2007              55000    Petrol       Manual
# 2530      BMW       Kochi  2014              64158    Diesel    Automatic
# 2542  Hyundai   Bangalore  2011              65000    Petrol       Manual
# 2623      BMW        Pune  2012              95000    Diesel    Automatic
# 2668   Maruti     Kolkata  2014              32986    Petrol       Manual
# 2737   Maruti      Jaipur  2001             200000    Petrol       Manual
# 2780  Hyundai        Pune  2009             100000    Petrol       Manual
# 2842  Hyundai   Bangalore  2012              43000    Petrol       Manual
# 3272      BMW      Mumbai  2008              81000    Diesel    Automatic
# 3404   Maruti      Jaipur  2006             125000    Petrol       Manual
# 3520      BMW       Delhi  2012              90000    Diesel    Automatic
# 3522  Hyundai       Kochi  2012              66400    Petrol       Manual
# 3810    Honda     Kolkata  2013              27000    Petrol    Automatic
# 4011     Fiat        Pune  2011              45271    Diesel       Manual
# 4152     Land      Mumbai  2003              75000    Diesel    Automatic
# 4229  Hyundai   Bangalore  2005              79000    Petrol       Manual
# 4577      BMW       Delhi  2012              72000    Diesel    Automatic
# 4604    Honda        Pune  2011              98000    Petrol       Manual
# 4697     Fiat       Kochi  2017              17941    Petrol       Manual
# 4712  Hyundai        Pune  2003              80000    Petrol       Manual
# 4952     Fiat     Kolkata  2010              47000    Petrol       Manual
# 5015   Maruti       Delhi  2006              63000    Petrol       Manual
# 5185   Maruti       Delhi  2012              52000    Petrol       Manual
# 5270    Honda   Bangalore  2002              53000    Petrol       Manual
#
#           Owner_Type  Mileage  Engine Power  Seats  Price  \
# 194            First     0.00     NaN  None    NaN   2.95
# 208            First    16.10     NaN  None    NaN   2.11
# 733            Third    16.10     NaN  None    NaN   1.75
# 749           Second     0.00     NaN  None    NaN  26.50
# 1294           First    12.80     NaN  None    NaN   3.20
# 1327           First    16.10     NaN  None    NaN   5.80
# 1385          Second     0.00     NaN  None    NaN   1.50
# 1460           First     0.00     NaN  None    NaN  40.88
# 2074           First    16.10     NaN  None    NaN   3.15
# 2096           First     0.00     NaN  None    NaN   1.93
# 2264          Second    18.30     NaN  None    NaN   2.95
# 2325           First    16.10     NaN  None    NaN   4.70
# 2335          Second    16.10     NaN  None    NaN   1.75
# 2530           First    18.48     NaN  None    NaN  17.89
# 2542          Second     0.00     NaN  None    NaN   3.15
# 2623          Second    18.48     NaN  None    NaN  18.00
# 2668           First    16.10     NaN  None    NaN   4.24
# 2737           First    12.00     NaN  None    NaN   0.70
# 2780           First     0.00     NaN  None    NaN   1.60
# 2842           First     0.00     NaN  None    NaN   3.25
# 3272          Second    18.48     NaN  None    NaN  10.50
# 3404  Fourth & Above    16.10     NaN  None    NaN   2.35
# 3520           First    18.48     NaN  None    NaN  14.50
# 3522           First     0.00     NaN  None    NaN   2.66
# 3810           First    14.00     NaN  None    NaN  11.99
# 4011           First    20.30     NaN  None    NaN   2.60
# 4152          Second     0.00     NaN  None    NaN  16.11
# 4229          Second    17.00     NaN  None    NaN   1.65
# 4577           Third    18.48     NaN  None    NaN  13.85
# 4604           First    16.70     NaN  None    NaN   3.15
# 4697           First    15.70     NaN  None    NaN   3.93
# 4712          Second    17.00     NaN  None    NaN   0.90
# 4952           First    14.60     NaN  None    NaN   1.49
# 5015           First    16.10     NaN  None    NaN   1.60
# 5185           First    16.10     NaN  None    NaN   3.65
# 5270          Second     0.00     NaN  None    NaN   1.85
#
#                                                   Model
# 194                             [Honda, City, 1.5, GXI]
# 208                           [Maruti, Swift, 1.3, VXi]
# 733                           [Maruti, Swift, 1.3, VXi]
# 749                 [Land, Rover, Range, Rover, 3.0, D]
# 1294                             [Honda, City, 1.3, DX]
# 1327                          [Maruti, Swift, 1.3, ZXI]
# 1385                            [Honda, City, 1.5, GXI]
# 1460  [Land, Rover, Range, Rover, Sport, 2005, 2012,...
# 2074                          [Maruti, Swift, 1.3, LXI]
# 2096                     [Hyundai, Santro, LP, zipPlus]
# 2264                           [Toyota, Etios, Liva, V]
# 2325                     [Maruti, Swift, 1.3, VXI, ABS]
# 2335                          [Maruti, Swift, 1.3, VXi]
# 2530                      [BMW, 5, Series, 520d, Sedan]
# 2542            [Hyundai, Santro, GLS, II, -, Euro, II]
# 2623                      [BMW, 5, Series, 520d, Sedan]
# 2668                          [Maruti, Swift, 1.3, VXi]
# 2737                             [Maruti, Wagon, R, Vx]
# 2780            [Hyundai, Santro, GLS, II, -, Euro, II]
# 2842            [Hyundai, Santro, GLS, II, -, Euro, II]
# 3272                      [BMW, 5, Series, 520d, Sedan]
# 3404                          [Maruti, Swift, 1.3, VXi]
# 3520                      [BMW, 5, Series, 520d, Sedan]
# 3522            [Hyundai, Santro, GLS, II, -, Euro, II]
# 3810                 [Honda, CR-V, AT, With, Sun, Roof]
# 4011                        [Fiat, Punto, 1.3, Emotion]
# 4152                [Land, Rover, Range, Rover, 3.0, D]
# 4229                        [Hyundai, Santro, Xing, XG]
# 4577                      [BMW, 5, Series, 520d, Sedan]
# 4604                     [Honda, Jazz, Select, Edition]
# 4697                        [Fiat, Punto, 1.2, Dynamic]
# 4712                        [Hyundai, Santro, Xing, XG]
# 4952                        [Fiat, Punto, 1.4, Emotion]
# 5015                          [Maruti, Swift, 1.3, VXi]
# 5185                          [Maruti, Swift, 1.3, LXI]
# 5270                            [Honda, City, 1.5, GXI]

# %%
df[df['Power'].isnull()]
# Out:
#          Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 194     Honda   Ahmedabad  2007              60006    Petrol       Manual
# 208    Maruti     Kolkata  2010              42001    Petrol       Manual
# 733    Maruti     Chennai  2006              97800    Petrol       Manual
# 749      Land      Mumbai  2008              55001    Diesel    Automatic
# 1294    Honda       Delhi  2009              55005    Petrol       Manual
# 1327   Maruti   Hyderabad  2015              50295    Petrol       Manual
# 1385    Honda        Pune  2004             115000    Petrol       Manual
# 1460     Land  Coimbatore  2008              69078    Petrol       Manual
# 2074   Maruti        Pune  2011              24255    Petrol       Manual
# 2096  Hyundai  Coimbatore  2004              52146    Petrol       Manual
# 2264   Toyota        Pune  2012              24500    Petrol       Manual
# 2325   Maruti        Pune  2015              67000    Petrol       Manual
# 2335   Maruti      Mumbai  2007              55000    Petrol       Manual
# 2530      BMW       Kochi  2014              64158    Diesel    Automatic
# 2542  Hyundai   Bangalore  2011              65000    Petrol       Manual
# 2623      BMW        Pune  2012              95000    Diesel    Automatic
# 2668   Maruti     Kolkata  2014              32986    Petrol       Manual
# 2737   Maruti      Jaipur  2001             200000    Petrol       Manual
# 2780  Hyundai        Pune  2009             100000    Petrol       Manual
# 2842  Hyundai   Bangalore  2012              43000    Petrol       Manual
# 3272      BMW      Mumbai  2008              81000    Diesel    Automatic
# 3404   Maruti      Jaipur  2006             125000    Petrol       Manual
# 3520      BMW       Delhi  2012              90000    Diesel    Automatic
# 3522  Hyundai       Kochi  2012              66400    Petrol       Manual
# 3810    Honda     Kolkata  2013              27000    Petrol    Automatic
# 4011     Fiat        Pune  2011              45271    Diesel       Manual
# 4152     Land      Mumbai  2003              75000    Diesel    Automatic
# 4229  Hyundai   Bangalore  2005              79000    Petrol       Manual
# 4577      BMW       Delhi  2012              72000    Diesel    Automatic
# 4604    Honda        Pune  2011              98000    Petrol       Manual
# 4697     Fiat       Kochi  2017              17941    Petrol       Manual
# 4712  Hyundai        Pune  2003              80000    Petrol       Manual
# 4952     Fiat     Kolkata  2010              47000    Petrol       Manual
# 5015   Maruti       Delhi  2006              63000    Petrol       Manual
# 5185   Maruti       Delhi  2012              52000    Petrol       Manual
# 5270    Honda   Bangalore  2002              53000    Petrol       Manual
#
#           Owner_Type  Mileage  Engine Power  Seats  Price  \
# 194            First     0.00     NaN  None    NaN   2.95
# 208            First    16.10     NaN  None    NaN   2.11
# 733            Third    16.10     NaN  None    NaN   1.75
# 749           Second     0.00     NaN  None    NaN  26.50
# 1294           First    12.80     NaN  None    NaN   3.20
# 1327           First    16.10     NaN  None    NaN   5.80
# 1385          Second     0.00     NaN  None    NaN   1.50
# 1460           First     0.00     NaN  None    NaN  40.88
# 2074           First    16.10     NaN  None    NaN   3.15
# 2096           First     0.00     NaN  None    NaN   1.93
# 2264          Second    18.30     NaN  None    NaN   2.95
# 2325           First    16.10     NaN  None    NaN   4.70
# 2335          Second    16.10     NaN  None    NaN   1.75
# 2530           First    18.48     NaN  None    NaN  17.89
# 2542          Second     0.00     NaN  None    NaN   3.15
# 2623          Second    18.48     NaN  None    NaN  18.00
# 2668           First    16.10     NaN  None    NaN   4.24
# 2737           First    12.00     NaN  None    NaN   0.70
# 2780           First     0.00     NaN  None    NaN   1.60
# 2842           First     0.00     NaN  None    NaN   3.25
# 3272          Second    18.48     NaN  None    NaN  10.50
# 3404  Fourth & Above    16.10     NaN  None    NaN   2.35
# 3520           First    18.48     NaN  None    NaN  14.50
# 3522           First     0.00     NaN  None    NaN   2.66
# 3810           First    14.00     NaN  None    NaN  11.99
# 4011           First    20.30     NaN  None    NaN   2.60
# 4152          Second     0.00     NaN  None    NaN  16.11
# 4229          Second    17.00     NaN  None    NaN   1.65
# 4577           Third    18.48     NaN  None    NaN  13.85
# 4604           First    16.70     NaN  None    NaN   3.15
# 4697           First    15.70     NaN  None    NaN   3.93
# 4712          Second    17.00     NaN  None    NaN   0.90
# 4952           First    14.60     NaN  None    NaN   1.49
# 5015           First    16.10     NaN  None    NaN   1.60
# 5185           First    16.10     NaN  None    NaN   3.65
# 5270          Second     0.00     NaN  None    NaN   1.85
#
#                                                   Model
# 194                             [Honda, City, 1.5, GXI]
# 208                           [Maruti, Swift, 1.3, VXi]
# 733                           [Maruti, Swift, 1.3, VXi]
# 749                 [Land, Rover, Range, Rover, 3.0, D]
# 1294                             [Honda, City, 1.3, DX]
# 1327                          [Maruti, Swift, 1.3, ZXI]
# 1385                            [Honda, City, 1.5, GXI]
# 1460  [Land, Rover, Range, Rover, Sport, 2005, 2012,...
# 2074                          [Maruti, Swift, 1.3, LXI]
# 2096                     [Hyundai, Santro, LP, zipPlus]
# 2264                           [Toyota, Etios, Liva, V]
# 2325                     [Maruti, Swift, 1.3, VXI, ABS]
# 2335                          [Maruti, Swift, 1.3, VXi]
# 2530                      [BMW, 5, Series, 520d, Sedan]
# 2542            [Hyundai, Santro, GLS, II, -, Euro, II]
# 2623                      [BMW, 5, Series, 520d, Sedan]
# 2668                          [Maruti, Swift, 1.3, VXi]
# 2737                             [Maruti, Wagon, R, Vx]
# 2780            [Hyundai, Santro, GLS, II, -, Euro, II]
# 2842            [Hyundai, Santro, GLS, II, -, Euro, II]
# 3272                      [BMW, 5, Series, 520d, Sedan]
# 3404                          [Maruti, Swift, 1.3, VXi]
# 3520                      [BMW, 5, Series, 520d, Sedan]
# 3522            [Hyundai, Santro, GLS, II, -, Euro, II]
# 3810                 [Honda, CR-V, AT, With, Sun, Roof]
# 4011                        [Fiat, Punto, 1.3, Emotion]
# 4152                [Land, Rover, Range, Rover, 3.0, D]
# 4229                        [Hyundai, Santro, Xing, XG]
# 4577                      [BMW, 5, Series, 520d, Sedan]
# 4604                     [Honda, Jazz, Select, Edition]
# 4697                        [Fiat, Punto, 1.2, Dynamic]
# 4712                        [Hyundai, Santro, Xing, XG]
# 4952                        [Fiat, Punto, 1.4, Emotion]
# 5015                          [Maruti, Swift, 1.3, VXi]
# 5185                          [Maruti, Swift, 1.3, LXI]
# 5270                            [Honda, City, 1.5, GXI]

# %%
df['Power'] = pd.to_numeric(df['Power'],errors='coerce')

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# Name                 0
# Location             0
# Year                 0
# Kilometers_Driven    0
# Fuel_Type            0
# Transmission         0
# Owner_Type           0
# Mileage              0
# Engine               0
# Power                0
# Seats                0
# Price                0
# Model                0
# dtype: int64

# %%
df
# Out:
#            Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0        Maruti      Mumbai  2010              72000       CNG       Manual
# 1       Hyundai        Pune  2015              41000    Diesel       Manual
# 2         Honda     Chennai  2011              46000    Petrol       Manual
# 3        Maruti     Chennai  2012              87000    Diesel       Manual
# 4          Audi  Coimbatore  2013              40670    Diesel    Automatic
# ...         ...         ...   ...                ...       ...          ...
# 6014     Maruti       Delhi  2014              27365    Diesel       Manual
# 6015    Hyundai      Jaipur  2015             100000    Diesel       Manual
# 6016   Mahindra      Jaipur  2012              55000    Diesel       Manual
# 6017     Maruti     Kolkata  2013              46000    Petrol       Manual
# 6018  Chevrolet   Hyderabad  2011              47000    Diesel       Manual
#
#      Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0         First    26.60   998.0   58.16    5.0   1.75
# 1         First    19.67  1582.0  126.20    5.0  12.50
# 2         First    18.20  1199.0   88.70    5.0   4.50
# 3         First    20.77  1248.0   88.76    7.0   6.00
# 4        Second    15.20  1968.0  140.80    5.0  17.74
# ...         ...      ...     ...     ...    ...    ...
# 6014      First    28.40  1248.0   74.00    5.0   4.75
# 6015      First    24.40  1120.0   71.00    5.0   4.00
# 6016     Second    14.00  2498.0  112.00    8.0   2.90
# 6017      First    18.90   998.0   67.10    5.0   2.65
# 6018      First    25.44   936.0   57.60    5.0   2.50
#
#                                         Model
# 0                [Maruti, Wagon, R, LXI, CNG]
# 1     [Hyundai, Creta, 1.6, CRDi, SX, Option]
# 2                            [Honda, Jazz, V]
# 3                       [Maruti, Ertiga, VDI]
# 4      [Audi, A4, New, 2.0, TDI, Multitronic]
# ...                                       ...
# 6014                     [Maruti, Swift, VDI]
# 6015           [Hyundai, Xcent, 1.1, CRDi, S]
# 6016               [Mahindra, Xylo, D4, BSIV]
# 6017                  [Maruti, Wagon, R, VXI]
# 6018                [Chevrolet, Beat, Diesel]
#
# [5862 rows x 13 columns]

# %% [markdown]
# TO DISPLAY ALL DATA TYPES

# %%
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# Model                 object
# dtype: object

# %% [markdown]
# FEATURE ENGINEERING AND VISULIZATION.

# %%
plt.figure(figsize=(12,10))
most_cat = df['Name'].value_counts()
sns.barplot(x=most_cat, y=most_cat.index, data=df)
plt.xticks(size=15)
plt.xlabel("Frequency",size=22,c="g")
plt.ylabel("Manufactures",size=22,c="g")
plt.title("Total Cars of all Companies",size=28,c="r")
plt.show()

# %%
df['Name'].value_counts()[df['Name'].value_counts()<5]
# Out:
# Force          3
# ISUZU          2
# Ambassador     1
# Isuzu          1
# Bentley        1
# Lamborghini    1
# Name: Name, dtype: int64

# %% [markdown]
# TO GROUP THE CARS COMPANIES WHO HAVE LESS THAN 5 CARS AND DROP THEM.

# %%
i = df['Name'].value_counts()[df['Name'].value_counts()<5].index
index = df[df['Name'].isin(i)].index
df.drop(index,axis=0,inplace=True)

# %% [markdown]
# TOTAL CAR LOCATION WISE.

# %%
plt.figure(figsize=(8,6))
most_cat = df['Location'].value_counts()
sns.barplot(x=most_cat, y=most_cat.index, data=df)
plt.xticks(size=15)
plt.xlabel("Frequency",size=15,c="g")
plt.ylabel("Location",size=15,c="g")
plt.title("Total Cars Location wise",size=22,c="r")
plt.show()

# %% [markdown]
# PRICE RANGE IN DIFFERENT MANUFACTURES

# %%
plt.figure(figsize=(12,8))
sns.boxplot(data=df,y="Name",x="Price")
plt.xlabel("Price",size=18,c="g")
plt.ylabel("Manufactures",size=18,c="g")
plt.title("Price range of differents manufactures",size=25,c="r")
plt.xticks(rotation='vertical',size=15)
plt.show()

# %% [markdown]
# ALL CATEGORY WITH THEIR RATING

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(data=df,y="Name",x='Price',color="m")
plt.xticks(rotation='vertical',size=15)
plt.xlabel("Rating",size=15,c="r")
plt.ylabel("Category",size=15,c="r")
plt.title("All Categ with their Rating",size=25,c="red")
plt.show()

# %% [markdown]
# RATING BY FULE TYPES

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df,x="Fuel_Type",y="Price")
plt.xlabel("Fuel Types",size=17,c="k")
plt.ylabel("Price",size=17,c="k")
plt.title("Fuel Types",size=25,c="red")
plt.show()

# %% [markdown]
# YEAR BY PRICE GRAPH

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df,x="Fuel_Type",y="Price")
plt.xlabel("Fuel Types",size=17,c="k")
plt.ylabel("Price",size=17,c="k")
plt.title("Fuel Types",size=25,c="red")
plt.show()

# %% [markdown]
# GRAPH FOR FREQUENCY BY SEATS

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df,x="Seats")
plt.xlabel("Seats",size=18,c="g")
plt.ylabel("Frequency",size=18,c="g")
plt.show()

# %% [markdown]
# GRAPH OF TOTAL PERCENTAGE OF OWNERS.

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.countplot(data=df,x="Owner_Type")
plt.xlabel("Owner Type",size=15,c="r")
plt.ylabel("Frequency",size=15,c="r")
plt.subplot(1,2,2)
labels =df['Owner_Type'].value_counts(sort = True).index
sizes = df['Owner_Type'].value_counts(sort = True)
plt.pie(sizes, labels=labels,autopct='%1.1f%%', shadow=True, startangle=270)
plt.title('Total % of Owner',size = 25,c="r")
plt.show()

# %% [markdown]
# STATISTICAL INFO ON NUM FEATURTES

# %%
df.describe()
df
# Out:
#            Name    Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 0        Maruti      Mumbai  2010              72000       CNG       Manual
# 1       Hyundai        Pune  2015              41000    Diesel       Manual
# 2         Honda     Chennai  2011              46000    Petrol       Manual
# 3        Maruti     Chennai  2012              87000    Diesel       Manual
# 4          Audi  Coimbatore  2013              40670    Diesel    Automatic
# ...         ...         ...   ...                ...       ...          ...
# 6014     Maruti       Delhi  2014              27365    Diesel       Manual
# 6015    Hyundai      Jaipur  2015             100000    Diesel       Manual
# 6016   Mahindra      Jaipur  2012              55000    Diesel       Manual
# 6017     Maruti     Kolkata  2013              46000    Petrol       Manual
# 6018  Chevrolet   Hyderabad  2011              47000    Diesel       Manual
#
#      Owner_Type  Mileage  Engine   Power  Seats  Price  \
# 0         First    26.60   998.0   58.16    5.0   1.75
# 1         First    19.67  1582.0  126.20    5.0  12.50
# 2         First    18.20  1199.0   88.70    5.0   4.50
# 3         First    20.77  1248.0   88.76    7.0   6.00
# 4        Second    15.20  1968.0  140.80    5.0  17.74
# ...         ...      ...     ...     ...    ...    ...
# 6014      First    28.40  1248.0   74.00    5.0   4.75
# 6015      First    24.40  1120.0   71.00    5.0   4.00
# 6016     Second    14.00  2498.0  112.00    8.0   2.90
# 6017      First    18.90   998.0   67.10    5.0   2.65
# 6018      First    25.44   936.0   57.60    5.0   2.50
#
#                                         Model
# 0                [Maruti, Wagon, R, LXI, CNG]
# 1     [Hyundai, Creta, 1.6, CRDi, SX, Option]
# 2                            [Honda, Jazz, V]
# 3                       [Maruti, Ertiga, VDI]
# 4      [Audi, A4, New, 2.0, TDI, Multitronic]
# ...                                       ...
# 6014                     [Maruti, Swift, VDI]
# 6015           [Hyundai, Xcent, 1.1, CRDi, S]
# 6016               [Mahindra, Xylo, D4, BSIV]
# 6017                  [Maruti, Wagon, R, VXI]
# 6018                [Chevrolet, Beat, Diesel]
#
# [5853 rows x 13 columns]

# %% [markdown]
# HANDLING THE OPUTLINERS

# %%
plt.figure(figsize=(11,7))
plt.subplot(1,1,1)
sns.distplot(df['Price'],color='r',kde_kws={'linewidth':3,'color':'b'});
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,y="Price",x='Location',hue='Fuel_Type')
plt.xlabel("Location",size=15,c="r")
plt.ylabel("Price",size=15,c="r")
plt.title("Effect of fuel type on Car price for location",size=25,c="red")
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.barplot(data=df,y="Price",x='Name',hue='Fuel_Type')
plt.xlabel("Location",size=15,c="r")
plt.ylabel("Price",size=15,c="r")
plt.xticks(rotation="vertical",size=10)
plt.title("Effect of fuel type on Price of differents brands",size=25,c="red")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,y="Price",x='Location',hue='Owner_Type')
plt.xlabel("Location",size=15,c="red")
plt.ylabel("Price",size=15,c="red")
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=df,y="Price",x='Location',hue='Owner_Type')
plt.xlabel("Location",size=15,c="red")
plt.ylabel("Price",size=15,c="red")
plt.show()

# %%
df_new = df.copy()

# %%
df.dtypes
# Out:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage              float64
# Engine               float64
# Power                float64
# Seats                float64
# Price                float64
# Model                 object
# dtype: object

# %% [markdown]
# TYPE OF OWNER

# %%
df['Owner_Type'].value_counts()
# Out:
# First             4824
# Second             923
# Third               99
# Fourth & Above       7
# Name: Owner_Type, dtype: int64

# %%
dic = {'First':2,'Second':1,'Third':0}
df['Year'].value_counts()
# Out:
# 2014    790
# 2015    740
# 2016    737
# 2013    639
# 2017    584
# 2012    558
# 2011    450
# 2010    331
# 2018    297
# 2009    191
# 2008    161
# 2007    104
# 2019    102
# 2006     65
# 2005     42
# 2004     25
# 2003     13
# 2002     11
# 2000      4
# 2001      4
# 1998      3
# 1999      2
# Name: Year, dtype: int64

# %% [markdown]
# MODEL TRANING

# %% [markdown]
# INPUT AND OUTPUT SECTION IN (X AND Y AXIS).

# %%
X = df.drop("Price",axis=1)   #X --- > Independent variables
Y= df['Price']
Y
# Out:
# 0        1.75
# 1       12.50
# 2        4.50
# 3        6.00
# 4       17.74
#         ...
# 6014     4.75
# 6015     4.00
# 6016     2.90
# 6017     2.65
# 6018     2.50
# Name: Price, Length: 5853, dtype: float64

# %% [markdown]
# TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)
X_train
# Out:
#             Name   Location  Year  Kilometers_Driven Fuel_Type Transmission  \
# 3616      Maruti    Chennai  2015              40000    Diesel       Manual
# 541        Honda     Mumbai  2016               9000    Petrol       Manual
# 2988      Toyota    Chennai  2005             240000    Diesel       Manual
# 1593     Hyundai  Hyderabad  2013              20000    Petrol       Manual
# 4483      Maruti       Pune  2017              33000    Petrol    Automatic
# ...          ...        ...   ...                ...       ...          ...
# 937   Volkswagen    Kolkata  2011              43000    Petrol       Manual
# 5339     Hyundai       Pune  2019               1000    Petrol       Manual
# 4099     Hyundai      Delhi  2018              10000    Petrol       Manual
# 246        Honda      Kochi  2016              33915    Petrol       Manual
# 5304         BMW  Bangalore  2017              21000    Diesel    Automatic
#
#           Owner_Type  Mileage  Engine   Power  Seats  \
# 3616           First    20.77  1248.0   88.80    7.0
# 541            First    18.00  1198.0   86.70    5.0
# 2988  Fourth & Above    12.80  2494.0  102.00    8.0
# 1593          Second    21.10   814.0   55.20    5.0
# 4483           First    21.40  1197.0   83.10    5.0
# ...              ...      ...     ...     ...    ...
# 937           Second    16.47  1198.0   73.90    5.0
# 5339           First    17.19  1197.0   81.86    5.0
# 4099           First    18.90  1197.0   81.86    5.0
# 246            First    17.80  1497.0  117.30    5.0
# 5304           First    21.76  1995.0  190.00    5.0
#
#                                                Model
# 3616                           [Maruti, Ertiga, ZDI]
# 541                   [Honda, Amaze, VX, O, i, VTEC]
# 2988     [Toyota, Innova, 2.5, G4, Diesel, 8-seater]
# 1593                     [Hyundai, EON, Magna, Plus]
# 4483               [Maruti, Baleno, Zeta, Automatic]
# ...                                              ...
# 937       [Volkswagen, Polo, Petrol, Highline, 1.2L]
# 5339  [Hyundai, i20, Active, SX, Dual, Tone, Petrol]
# 4099         [Hyundai, Grand, i10, 1.2, Kappa, Asta]
# 246                        [Honda, City, i, VTEC, V]
# 5304                  [BMW, 3, Series, Luxury, Line]
#
# [4097 rows x 12 columns]
